# %%
import numpy as np

# %%
a=np.array([1,2,3],dtype="int32")
print(a)
# Out:
# [1 2 3]

# %%
b=np.array([[3.0,8.0],[6.0,5.0]])
print(b)
# Out:
# [[3. 8.]
#  [6. 5.]]

# %%
#get dimension
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (3,)

# %%
#get type and size
a.dtype
# Out:
# dtype('int16')

# %%
#get size
a.nbytes
# Out:
# 6
